# %% [markdown]
# <a href="https://colab.research.google.com/github/ratimayy/deep/blob/main/MLP2_ex1_1_StaticViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Prepare the environment

# %%
# List all NVIDIA GPUs as available in this computer (or Colab's session)
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA L4 (UUID: GPU-c8797ec2-8e5d-2b3f-5953-540325e38b12)

# %%
import sys
print( f"Python {sys.version}\n" )

import os

import numpy as np
print( f"NumPy {np.__version__}\n" )

import pandas as pd
print( f"Pandas {pd.__version__}\n" )

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
print( f"Matplotlib {matplotlib.__version__}\n" )

import tensorflow as tf
print( f"TensorFlow {tf.__version__}" )
print( f"tf.keras.backend.image_data_format() = {tf.keras.backend.image_data_format()}" )

# Count the number of GPUs as detected by tensorflow
gpus = tf.config.list_physical_devices('GPU')
print( f"TensorFlow detected { len(gpus) } GPU(s):" )
for i, gpu in enumerate(gpus):
  print( f".... GPU No. {i}: Name = {gpu.name} , Type = {gpu.device_type}" )
# Out:
# Python 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#
# NumPy 1.26.4
#
# Pandas 2.1.4
#
# Matplotlib 3.7.1
#
# TensorFlow 2.17.0
# tf.keras.backend.image_data_format() = channels_last
# TensorFlow detected 1 GPU(s):
# .... GPU No. 0: Name = /physical_device:GPU:0 , Type = GPU

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed
#np.random.seed(1234)
#tf.random.set_seed(5678)

# %% [markdown]
# # 2. Prepare the dataset
#
# Load the Boston Housing dataset (http://lib.stat.cmu.edu/datasets/boston) from Keras

# %%
# Load
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.boston_housing.load_data()

# Inspect
vars = [ ('x_train',x_train), ('y_train',y_train), ('x_test',x_test), ('y_test',y_test) ]
for name,var in vars:
  print(f"{name}: type={type(var)} , shape={var.shape} , dtype={var.dtype}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train: type=<class 'numpy.ndarray'> , shape=(404, 13) , dtype=float64
# y_train: type=<class 'numpy.ndarray'> , shape=(404,) , dtype=float64
# x_test: type=<class 'numpy.ndarray'> , shape=(102, 13) , dtype=float64
# y_test: type=<class 'numpy.ndarray'> , shape=(102,) , dtype=float64

# %% [markdown]
# (Optional) Preview the train and test sets with pandas' dataframe

# %%
# A function to convert two numpy arrays to a single dataframe
def boston_dataframe(np_x, np_y):
  # Create a dataframe from two numpy arrays
  columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
  df_boston = pd.DataFrame(np_x, columns=columns)   # 13 feature columns
  df_boston['MEDV'] = pd.Series(np_y)   # 1 output column

  return df_boston

# Preview stats regarding both train and test datasets
print('===== PREVIEW: THE TRAIN SET =====')
display( boston_dataframe(x_train, y_train).describe().style.format(precision=2) )
print('\n===== PREVIEW: THE TEST SET =====')
display( boston_dataframe(x_test, y_test).describe().style.format(precision=2) )
# Out:
# ===== PREVIEW: THE TRAIN SET =====
# <style type="text/css">
# </style>
# <table id="T_9332f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9332f_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_9332f_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_9332f_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_9332f_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_9332f_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_9332f_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_9332f_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_9332f_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_9332f_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_9332f_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_9332f_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_9332f_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_9332f_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_9332f_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9332f_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_9332f_row0_col0" class="data row0 col0" >404.00</td>
#       <td id="T_9332f_row0_col1" class="data row0 col1" >404.00</td>
#       <td id="T_9332f_row0_col2" class="data row0 col2" >404.00</td>
#       <td id="T_9332f_row0_col3" class="data row0 col3" >404.00</td>
#       <td id="T_9332f_row0_col4" class="data row0 col4" >404.00</td>
#       <td id="T_9332f_row0_col5" class="data row0 col5" >404.00</td>
#       <td id="T_9332f_row0_col6" class="data row0 col6" >404.00</td>
#       <td id="T_9332f_row0_col7" class="data row0 col7" >404.00</td>
#       <td id="T_9332f_row0_col8" class="data row0 col8" >404.00</td>
#       <td id="T_9332f_row0_col9" class="data row0 col9" >404.00</td>
#       <td id="T_9332f_row0_col10" class="data row0 col10" >404.00</td>
#       <td id="T_9332f_row0_col11" class="data row0 col11" >404.00</td>
#       <td id="T_9332f_row0_col12" class="data row0 col12" >404.00</td>
#       <td id="T_9332f_row0_col13" class="data row0 col13" >404.00</td>
#     </tr>
#     <tr>
#       <th id="T_9332f_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_9332f_row1_col0" class="data row1 col0" >3.75</td>
#       <td id="T_9332f_row1_col1" class="data row1 col1" >11.48</td>
#       <td id="T_9332f_row1_col2" class="data row1 col2" >11.10</td>
#       <td id="T_9332f_row1_col3" class="data row1 col3" >0.06</td>
#       <td id="T_9332f_row1_col4" class="data row1 col4" >0.56</td>
#       <td id="T_9332f_row1_col5" class="data row1 col5" >6.27</td>
#       <td id="T_9332f_row1_col6" class="data row1 col6" >69.01</td>
#       <td id="T_9332f_row1_col7" class="data row1 col7" >3.74</td>
#       <td id="T_9332f_row1_col8" class="data row1 col8" >9.44</td>
#       <td id="T_9332f_row1_col9" class="data row1 col9" >405.90</td>
#       <td id="T_9332f_row1_col10" class="data row1 col10" >18.48</td>
#       <td id="T_9332f_row1_col11" class="data row1 col11" >354.78</td>
#       <td id="T_9332f_row1_col12" class="data row1 col12" >12.74</td>
#       <td id="T_9332f_row1_col13" class="data row1 col13" >22.40</td>
#     </tr>
#     <tr>
#       <th id="T_9332f_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T
level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_9332f_row5_col0" class="data row5 col0" >0.27</td>
#       <td id="T_9332f_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_9332f_row5_col2" class="data row5 col2" >9.69</td>
#       <td id="T_9332f_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_9332f_row5_col4" class="data row5 col4" >0.54</td>
#       <td id="T_9332f_row5_col5" class="data row5 col5" >6.20</td>
#       <td id="T_9332f_row5_col6" class="data row5 col6" >78.50</td>
#       <td id="T_9332f_row5_col7" class="data row5 col7" >3.14</td>
#       <td id="T_9332f_row5_col8" class="data row5 col8" >5.00</td>
#       <td id="T_9332f_row5_col9" class="data row5 col9" >330.00</td>
#       <td id="T_9332f_row5_col10" class="data row5 col10" >19.10</td>
#       <td id="T_9332f_row5_col11" class="data row5 col11" >391.25</td>
#       <td id="T_9332f_row5_col12" class="data row5 col12" >11.39</td>
#       <td id="T_9332f_row5_col13" class="data row5 col13" >20.75</td>
#     </tr>
#     <tr>
#       <th id="T_9332f_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_9332f_row6_col0" class="data row6 col0" >3.67</td>
#       <td id="T_9332f_row6_col1" class="data row6 col1" >12.50</td>
#       <td id="T_9332f_row6_col2" class="data row6 col2" >18.10</td>
#       <td id="T_9332f_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_9332f_row6_col4" class="data row6 col4" >0.63</td>
# ===== PREVIEW: THE TEST SET =====
# <style type="text/css">
# </style>
# <table id="T_3e68c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e68c_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_3e68c_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_3e68c_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_3e68c_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_3e68c_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_3e68c_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_3e68c_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_3e68c_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_3e68c_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_3e68c_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_3e68c_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_3e68c_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_3e68c_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_3e68c_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e68c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_3e68c_row0_col0" class="data row0 col0" >102.00</td>
#       <td id="T_3e68c_row0_col1" class="data row0 col1" >102.00</td>
#       <td id="T_3e68c_row0_col2" class="data row0 col2" >102.00</td>
#       <td id="T_3e68c_row0_col3" class="data row0 col3" >102.00</td>
#       <td id="T_3e68c_row0_col4" class="data row0 col4" >102.00</td>
#       <td id="T_3e68c_row0_col5" class="data row0 col5" >102.00</td>
#       <td id="T_3e68c_row0_col6" class="data row0 col6" >102.00</td>
#       <td id="T_3e68c_row0_col7" class="data row0 col7" >102.00</td>
#       <td id="T_3e68c_row0_col8" class="data row0 col8" >102.00</td>
# 'axis' = Axis or axes along which the means are computed. The default is to compute the mean of the flattened array.
mean = x_train.mean(axis=0)   # https://numpy.org/doc/stable/reference/generated/numpy.mean.html
sd = x_train.std(axis=0)      # https://numpy.org/doc/stable/reference/generated/numpy.std.html
print(f"{mean.shape=} , {sd.shape=}\n")

# Normalize 13 features
x_train_norm = ( x_train - mean ) / sd
x_test_norm = ( x_test - mean ) / sd

# Inspect
print('===== PREVIEW: TRAIN SET AFTER NORM =====')
display( boston_dataframe(x_train_norm, y_train).describe().style.format(precision=2) )
print('\n===== PREVIEW: TEST SET AFTER NORM =====')
display( boston_dataframe(x_test_norm, y_test).describe().style.format(precision=2) )
# Out:
# mean.shape=(13,) , sd.shape=(13,)
#
# ===== PREVIEW: TRAIN SET AFTER NORM =====
# <style type="text/css">
# </style>
# <table id="T_1271d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1271d_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_1271d_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_1271d_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_1271d_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_1271d_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_1271d_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_1271d_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_1271d_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_1271d_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_1271d_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_1271d_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_1271d_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_1271d_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_1271d_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1271d_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1271d_row0_col0" class="data row0 col0" >404.00</td>
#       <td id="T_1271d_row0_col1" class="data row0 col1" >404.00</td>
#       <td id="T_1271d_row0_col2" class="data row0 col2" >404.00</td>
#       <td id="T_1271d_row0_col3" class="data row0 col3" >404.00</td>
#       <td id="T_1271d_row0_col4" class="data row0 col4" >404.00</td>
#       <td id="T_1271d_row0_col5" class="data row0 col5" >404.00</td>
#       <td id="T_1271d_row0_col6" class="data row0 col6" >404.00</td>
#       <td id="T_1271d_row0_col7" class="data row0 col7" >404.00</td>
#       <td id="T_1271d_row0_col8" class="data row0 col8" >404.00</td>
#       <td id="T_1271d_row0_col9" class="data row0 col9" >404.00</td>
#       <td id="T_1271d_row0_col10" class="data row0 col10" >404.00</td>
#       <td id="T_1271d_row0_col11" class="data row0 col11" >404.00</td>
#       <td id="T_1271d_row0_col12" class="data row0 col12" >404.00</td>
#       <td id="T_1271d_row0_col13" class="data row0 col13" >404.00</td>
#     </tr>
#     <tr>
#       <th id="T_1271d_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T
level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_1271d_row4_col0" class="data row4 col0" >-0.40</td>
#       <td id="T_1271d_row4_col1" class="data row4 col1" >-0.48</td>
#       <td id="T_1271d_row4_col2" class="data row4 col2" >-0.88</td>
#       <td id="T_1271d_row4_col3" class="data row4 col3" >-0.26</td>
#       <td id="T_1271d_row4_col4" class="data row4 col4" >-0.89</td>
#       <td id="T_1271d_row4_col5" class="data row4 col5" >-0.55</td>
#       <td id="T_1271d_row4_col6" class="data row4 col6" >-0.84</td>
#       <td id="T_1271d_row4_col7" class="data row4 col7" >-0.82</td>
#       <td id="T_1271d_row4_col8" class="data row4 col8" >-0.63</td>
#       <td id="T_1271d_row4_col9" class="data row4 col9" >-0.76</td>
#       <td id="T_1271d_row4_col10" class="data row4 col10" >-0.57</td>
#       <td id="T_1271d_row4_col11" class="data row4 col11" >0.21</td>
#       <td id="T_1271d_row4_col12" class="data row4 col12" >-0.81</td>
#       <td id="T_1271d_row4_col13" class="data row4 col13" >16.68</td>
#     </tr>
#     <tr>
#       <th id="T_1271d_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_1271d_row5_col0" class="data row5 col0" >-0.38</td>
#       <td id="T_1271d_row5_col1" class="data row5 col1" >-0.48</td>
#       <td id="T_1271d_row5_col2" class="data row5 col2" >-0.21</td>
#       <td id="T_1271d_row5_col3" class="data row5 col3" >-0.26</td>
#       <td id="T_1271d_row5_col4" class="data row5 col4" >-0.17</td>
#       <td id="T_1271d_row5_col5" class="data row5 col5" >-0.10</td>
#       <td id="T_1271d_row5_col6" class="data row5 col6" >0.34</td>
#       <td id="T_1271d_row5_col7" class="data row5 col7" >-0.29</td>
#       <td id="T_1271d_row5_col8" class="data row5 col8" >-0.51</td>
#       <td id="T_1271d_row5_col9" class="data row5 col9" >-0.46</td>
#       <td id="T_1271d_row5_col10" class="data row5 col10" >0.28</td>
#       <td id="T_1271d_row5_col11" class="data row5 col11" >0.39</td>
#       <td id="T_1271d_row5_col12" class="data row5 col12" >-0.19</td>
#       <td id="T_1271d_row5_col13" class="data row5 col13" >20.75</td>
#     </tr>
#     <tr>
#       <th id="T_1271d_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_1271d_row6_col0" class="data row6 col0" >-0.01</td>
#       <td id="T_1271d_row6_col1" class="data row6 col1" >0.04</td>
#       <td id="T_1271d_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_1271d_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_1271d_row6_col4" class="data row6 col4" >0.
# ===== PREVIEW: TEST SET AFTER NORM =====
# <style type="text/css">
# </style>
# <table id="T_e12b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e12b0_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_e12b0_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_e12b0_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_e12b0_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_e12b0_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_e12b0_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_e12b0_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_e12b0_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_e12b0_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_e12b0_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_e12b0_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_e12b0_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_e12b0_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_e12b0_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e12b0_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e12b0_row0_col0" class="data row0 col0" >102.00</td>
#       <td id="T_e12b0_row0_col1" class="data row0 col1" >102.00</td>
#       <td id="T_e12b0_row0_col2" class="data row0 col2" >102.00</td>
#       <td id="T_e12b0_row0_col3" class="data row0 col3" >102.00</td>
#       <td id="T_e12b0_row0_col4" class="data row0 col4" >102.00</td>
#       <td id="T_e12b0_row0_col5" class="data row0 col5" >102.00</td>
#       <td id="T_e12b0_row0_col6" class="data row0 col6" >102.00</td>
#       <td id="T_e12b0_row0_col7" class="data row0 col7" >102.00</td>
#       <td id="T_e12b0_row0_col8" class="data row0 col8" >102.00</td>
#       <td id="T_e12b0_row0_col9" class="data row0 col9" >102.00</td>
#       <td id="T_e12b0_row0_col10" class="data row0 col10" >102.00</td>
#       <td id="T_e12b0_row0_col11" class="data row0 col11" >102.00</td>
#       <td id="T_e12b0_row0_col12" class="data row0 col12" >102.00</td>
#       <td id="T_e12b0_row0_col13" class="data row0 col13" >102.00</td>
#     </tr>
#     <tr>
#       <th id="T_e12b0_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_e12b0_row1_col0" class="data row1 col0" >-0.07</td>
#       <td id="T_e12b0_row1_col1" class="data row1 col1" >-0.02</td>
#       <td id="T_e12b0_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_e12b0_row1_col3" class="data row1 col3" >0.15</td>
#       <td id="T_e12b0_row1_col4" class="data row1 col4" >-0.11</td>
#       <td id="T_e12b0_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_e12b0_row1_col6" class="data row1 col6" >-0.08</td>
#       <td id="T_e12b0_row1_col7" class="data row1 col7" >0.13</td>
#       <td id="T_e12b0_row1_col8" class="data row1 col8" >0.06</td>
#       <td id="T_e12b0_row1_col9" class="data row1 col9" >0.07</td>
#       <td id="T_e12b0_row1_col10" class="data row1 col10" >-0.05</td>
#       <td id="T_e12b0_row1_col11" class="data row1 col11" >0.10</td>
#       <td id="T_e12b0_row1_col12" class="data row1 col12" >-0.06</td>
#       <td id="T_e12b0_row1_col13" class="data row1 col13" >23.08</td>
#     </tr>
#     <tr>
#       <th id="T_e12b0_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_e12b0_row2_col0" class="data row2 col0" >0.58</td>
#       <td id="T_e12b0_row2_col1" class="data row2 col1" >0.91</td>
#       <td id="T_e12b0_row2_col2" class="data row2 col2" >1.04</td>
#       <td id="T_e12b0_row2_col3" class="data row2 col3" >1.24</td>
#       <td id="T_e12b0_row2_col4" class="data row2 col4" >0.94</td>
#       <td id="T_e12b0_row2_col5" class="data row2 col5" >0.95</td>
#       <td id="T_e12b0_row2_col6" class="data row2 col6" >1.04</td>
#       <td id="T_e12b0_row2_col7" class="data row2 col7" >1.17</td>
#       <td id="T_e12b0_row5_col6" class="data row5 col6" >0.17</td>
#       <td id="T_e12b0_row5_col7" class="data row5 col7" >-0.20</td>
#       <td id="T_e12b0_row5_col8" class="data row5 col8" >-0.51</td>
#       <td id="T_e12b0_row5_col9" class="data row5 col9" >-0.46</td>
#       <td id="T_e12b0_row5_col10" class="data row5 col10" >0.19</td>
#       <td id="T_e12b0_row5_col11" class="data row5 col11" >0.40</td>
#       <td id="T_e12b0_row5_col12" class="data row5 col12" >-0.23</td>
#       <td id="T_e12b0_row5_col13" class="data row5 col13" >21.95</td>
#     </tr>
#     <tr>
#       <th id="T_e12b0_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_e12b0_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_e12b0_row6_col1" class="data row6 col1" >0.20</td>
#       <td id="T_e12b0_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_e12b0_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_e12b0_row6_col4" class="data row6 col4" >0.

# %% [markdown]
# For data to be processed by the model, convert them to float32 dtype

# %%
# A conversion function
convert = lambda a: a.astype(np.float32)

# Convert and inspect
vars = [ ('x_train_norm',x_train_norm), ('y_train',y_train), ('x_test_norm',x_test_norm), ('y_test',y_test) ]
for name,var in vars:
  var = convert(var)
  print(f"{name}: type={type(var)} , shape={var.shape} , dtype={var.dtype}")
# Out:
# x_train_norm: type=<class 'numpy.ndarray'> , shape=(404, 13) , dtype=float32
# y_train: type=<class 'numpy.ndarray'> , shape=(404,) , dtype=float32
# x_test_norm: type=<class 'numpy.ndarray'> , shape=(102, 13) , dtype=float32
# y_test: type=<class 'numpy.ndarray'> , shape=(102,) , dtype=float32

# %% [markdown]
# # 3. Create the network architecture

# %%
def create_model():
  model = tf.keras.models.Sequential()

  # Input layer
  model.add( tf.keras.Input(shape=(x_train_norm.shape[-1],), name='input') )

  # Hidden layers
  model.add( tf.keras.layers.Dense(8, activation='relu', name='hidden1') )   # Use default weight initialization, don't use any regularization
  model.add( tf.keras.layers.BatchNormalization(axis=-1, name='bn1') )
  model.add( tf.keras.layers.Dense(16, activation='relu', name='hidden2') )  # Use default weight initialization, don't use any regularization
  model.add( tf.keras.layers.BatchNormalization(axis=-1, name='bn2') )
  model.add( tf.keras.layers.Dense(8, activation='relu', name='hidden3') )   # Use default weight initialization, don't use any regularization
  model.add( tf.keras.layers.Dropout(0.3) )          # drop rate = 30%

  # Output layer: For a regression problem, use a linear activation function (a.k.a., use no activation function)
  model.add( tf.keras.layers.Dense(1, name='output') )

  # Compile with default values for both optimizer and loss
  model.compile( optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'] )

  return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ hidden1 (Dense)                      │ (None, 8)                   │             112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bn1 (BatchNormalization)             │ (None, 8)                   │              32 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hidden2 (Dense)                      │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bn2 (BatchNormalization)             │ (None, 16)                  │              64 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hidden3 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output (Dense)                       │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 497 (1.94 KB)
#  Trainable params: 449 (1.75 KB)
#  Non-trainable params: 48 (192.00 B)

# %% [markdown]
# # 4. Train the model on train set

# %% [markdown]
# According to https://keras.io/guides/serialization_and_saving/:
# - A Keras model consists of multiple components:
#   - The architecture, or configuration, which specifies what layers the model contain, and how they're connected.
#   - A set of weights values (the "state of the model").
#   - An optimizer (defined by compiling the model).
#   - A set of losses and metrics (defined by compiling the model).
# - The Keras API saves all of the above components together in a unified format, marked by the `.keras` extension. This is a zip archive consisting of the following:
#   - A JSON-based configuration file (`config.json`): Records of model, layer, and other trackables' configuration.
#   - A H5-based state file, such as `model.weights.h5` (for the whole model), with directory keys for layers and their weights.
#   - A metadata file in JSON, storing things such as the current Keras version.
# - There are 3 alternative formats to save a Keras model:
#   1. (Legacy) TensorFlow SavedModel format
#     - Passing `save_format='tf'` to `model.save()`
#     - Passing a filename without an extension
#   2. (Legacy) Keras H5 format
#     - Passing `save_format='h5'` to `model.save()`
#     - Passing a filename that ends in .h5
#   3. (Recommend) Keras v3
#     - Passing `save_format='keras'` to `model.save()`
#     - The file needs to end with the .keras extension. For example, `model.save('path/to/location.keras')`
#     - In Keras 3, this is the only supported format.

# %%
menu = '\n1. Save weights only\n2. Save the full model\nYour choice: '

while True:
  choice = input(menu).strip()
  if choice in ['1', '2']:
    save_weights_only = True if choice=='1' else False
    break
# Out:
# 1. Save weights only
# 2. Save the full model
# Your choice: 2

# %%
if save_weights_only:
  checkpoint_filepath = "bestmodel_epoch{epoch:03d}_valloss{val_loss:.2f}.weights.h5"
else:
  checkpoint_filepath = "bestmodel_epoch{epoch:03d}_valloss{val_loss:.2f}.keras"

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint( filepath=checkpoint_filepath,
                                                                save_weights_only=save_weights_only,
                                                                monitor='val_loss',
                                                                mode='min',
                                                                save_best_only=True )

# %% [markdown]
# ModelCheckpoint ประมาณว่าเอาไว้เซฟโมเดล

# %% [markdown]
# If you encounter a case where validation loss is lower than train loss, read this article for explanation https://towardsdatascience.com/what-your-validation-loss-is-lower-than-your-training-loss-this-is-why-5e92e0b1747e.

# %% [markdown]
# เพราะ fit แทรกโค้ดลำบาก เลยมี callback ไว้แทรกได้

# %%
history = model.fit ( x_train_norm, y_train,
                      validation_split=0.2,
                      batch_size=32, epochs=100, verbose=1,
                      callbacks=[model_checkpoint_callback]
                  )
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - loss: 566.6815 - mean_absolute_error: 22.0196 - val_loss: 652.9751 - val_mean_absolute_error: 23.8030
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 581.7485 - mean_absolute_error: 22.2097 - val_loss: 643.9344 - val_mean_absolute_error: 23.6411
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 585.8735 - mean_absolute_error: 22.3934 - val_loss: 635.8034 - val_mean_absolute_error: 23.4970
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 552.6659 - mean_absolute_error: 21.5998 - val_loss: 627.2944 - val_mean_absolute_error: 23.3498
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 607.5979 - mean_absolute_error: 22.7459 - val_loss: 619.3920 - val_mean_absolute_error: 23.2123
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 566.9191 - mean_absolute_error: 22.0790 - val_loss: 611.1314 - val_mean_absolute_error: 23.0670
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 543.0455 - mean_absolute_error: 21.6155 - val_loss: 602.5911 - val_mean_absolute_error: 22.9166
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 492.5227 - mean_absolute_error: 20.7581 - val_loss: 593.3025 - val_mean_absolute_error: 22.7536
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 534.8784 - mean_absolute_error: 21.6269 - val_loss: 583.5997 - val_mean_absolute_error: 22.5837
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 498.7219 - mean_absolute_error: 20.9754 - val_loss: 571.5594 - val_mean_absolute_error: 22.3683
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 533.0547 - mean_absolute_error: 21.3130 - val_loss: 560.0249 - val_mean_absolute_error: 22.1570
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 498.8692 - mean_absolute_error: 20.7890 - val_loss: 547.9713 - val_mean_absolute_error: 21.9280
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 474.0451 - mean_absolute_error: 20.3247 - val_loss: 534.6867 - val_mean_absolute_error: 21.6706
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 463.9378 - mean_absolute_error: 19.9299 - val_loss: 521.6431 - val_mean_absolute_error: 21.4144
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 476.0691 - mean_absolute_error: 20.4591 - val_loss: 505.9579 - val_mean_absolute_error: 21.0990
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 437.2002 - mean_absolute_error: 19.5608 - val_loss: 491.1780 - val_mean_absolute_error: 20.7837
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 446.3414 - mean_absolute_error: 19.7953 - val_loss: 473.0976 - val_mean_absolute_error: 20.3963
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 455.0785 - mean_absolute_error: 19.7928 - val_loss: 454.6623 - val_mean_absolute_error: 19.9801
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 411.9391 - mean_absolute_error: 18.8601 - val_loss: 435.6686 - val_mean_absolute_error: 19.5337
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 422.6967 - mean_absolute_error: 19.0943 - val_loss: 413.7405 - val_mean_absolute_error: 18.9938
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 375.9915 - mean_absolute_error: 17.8824 - val_loss: 394.1445 - val_mean_absolute_error: 18.4877
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 360.8292 - mean_absolute_error: 17.7183 - val_loss: 373.7617 - val_mean_absolute_error: 17.9279
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 371.4624 - mean_absolute_error: 17.6198 - val_loss: 357.2110 - val_mean_absolute_error: 17.4449
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 355.5546 - mean_absolute_error: 17.2633 - val_loss: 336.0272 - val_mean_absolute_error: 16.8213
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 311.1263 - mean_absolute_error: 16.2417 - val_loss: 319.5166 - val_mean_absolute_error: 16.3052
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 324.3708 - mean_absolute_error: 16.2654 - val_loss: 298.9048 - val_mean_absolute_error: 15.6211
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 316.2760 - mean_absolute_error: 16.0244 - val_loss: 281.1658 - val_mean_absolute_error: 14.9990
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 293.6787 - mean_absolute_error: 15.3267 - val_loss: 264.5240 - val_mean_absolute_error: 14.3738
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 276.0385 - mean_absolute_error: 14.9488 - val_loss: 248.4524 - val_mean_absolute_error: 13.7064
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 276.8483 - mean_absolute_error: 14.4936 - val_loss: 233.4131 - val_mean_absolute_error: 13.0658
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 245.8096 - mean_absolute_error: 13.6742 - val_loss: 219.1563 - val_mean_absolute_error: 12.4120
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 235.4014 - mean_absolute_error: 13.1912 - val_loss: 206.1048 - val_mean_absolute_error: 11.8080
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 231.0085 - mean_absolute_error: 13.2425 - val_loss: 198.7179 - val_mean_absolute_error: 11.4908
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 200.2928 - mean_absolute_error: 12.2711 - val_loss: 189.5273 - val_mean_absolute_error: 11.0934
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 238.3401 - mean_absolute_error: 12.9972 - val_loss: 178.8774 - val_mean_absolute_error: 10.6350
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 204.2829 - mean_absolute_error: 12.1396 - val_loss: 167.7654 - val_mean_absolute_error: 10.1866
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 209.2756 - mean_absolute_error: 12.3816 - val_loss: 159.1389 - val_mean_absolute_error: 9.8654
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 220.2216 - mean_absolute_error: 12.7096 - val_loss: 150.4884 - val_mean_absolute_error: 9.5161
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 234.7917 - mean_absolute_error: 12.6827 - val_loss: 142.5962 - val_mean_absolute_error: 9.2108
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 198.1395 - mean_absolute_error: 11.7293 - val_loss: 133.3611 - val_mean_absolute_error: 8.8548
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 170.7302 - mean_absolute_error: 11.0295 - val_loss: 124.0430 - val_mean_absolute_error: 8.4754
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 147.7318 - mean_absolute_error: 10.1469 - val_loss: 114.9130 - val_mean_absolute_error: 8.0946
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 176.5558 - mean_absolute_error: 11.1378 - val_loss: 107.0992 - val_mean_absolute_error: 7.7534
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 190.2581 - mean_absolute_error: 11.4604 - val_loss: 100.8218 - val_mean_absolute_error: 7.4745
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 204.4416 - mean_absolute_error: 11.6085 - val_loss: 95.0004 - val_mean_absolute_error: 7.1857
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 149.6102 - mean_absolute_error: 9.8834 - val_loss: 90.3289 - val_mean_absolute_error: 6.9211
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 164.0086 - mean_absolute_error: 10.0819 - val_loss: 86.1464 - val_mean_absolute_error: 6.6706
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 168.0693 - mean_absolute_error: 9.9646 - val_loss: 81.1763 - val_mean_absolute_error: 6.3833
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 146.0968 - mean_absolute_error: 9.9194 - val_loss: 77.6741 - val_mean_absolute_error: 6.1499
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 147.3810 - mean_absolute_error: 9.6211 - val_loss: 73.7943 - val_mean_absolute_error: 5.9231
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 140.8477 - mean_absolute_error: 9.4810 - val_loss: 71.3282 - val_mean_absolute_error: 5.8129
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 122.9012 - mean_absolute_error: 9.0673 - val_loss: 69.5732 - val_mean_absolute_error: 5.6942
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 137.7361 - mean_absolute_error: 9.1649 - val_loss: 68.4226 - val_mean_absolute_error: 5.5480
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 127.6511 - mean_absolute_error: 8.8490 - val_loss: 69.4635 - val_mean_absolute_error: 5.5827
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 132.7452 - mean_absolute_error: 8.9455 - val_loss: 67.5010 - val_mean_absolute_error: 5.4629
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 136.1230 - mean_absolute_error: 9.0145 - val_loss: 64.9100 - val_mean_absolute_error: 5.3035
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 129.5032 - mean_absolute_error: 8.5281 - val_loss: 63.5333 - val_mean_absolute_error: 5.2341
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 113.5349 - mean_absolute_error: 8.2863 - val_loss: 62.5783 - val_mean_absolute_error: 5.1956
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 122.0396 - mean_absolute_error: 8.5308 - val_loss: 60.9801 - val_mean_absolute_error: 5.1273
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 107.7210 - mean_absolute_error: 8.0340 - val_loss: 59.8646 - val_mean_absolute_error: 5.1071
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 95.0660 - mean_absolute_error: 7.7019 - val_loss: 59.8406 - val_mean_absolute_error: 5.1354
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 110.8314 - mean_absolute_error: 8.0940 - val_loss: 60.2546 - val_mean_absolute_error: 5.1863
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 111.6962 - mean_absolute_error: 8.0010 - val_loss: 58.6000 - val_mean_absolute_error: 5.1046
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 96.5736 - mean_absolute_error: 7.5439 - val_loss: 55.8888 - val_mean_absolute_error: 5.0089
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 109.4110 - mean_absolute_error: 8.1414 - val_loss: 54.5579 - val_mean_absolute_error: 4.9433
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 130.9256 - mean_absolute_error: 8.7026 - val_loss: 52.1353 - val_mean_absolute_error: 4.8575
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 119.4388 - mean_absolute_error: 8.0869 - val_loss: 52.0508 - val_mean_absolute_error: 4.8670
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 105.7880 - mean_absolute_error: 8.1970 - val_loss: 52.3375 - val_mean_absolute_error: 4.9241
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 109.5157 - mean_absolute_error: 8.1253 - val_loss: 50.3742 - val_mean_absolute_error: 4.8239
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 96.7899 - mean_absolute_error: 7.8998 - val_loss: 48.8455 - val_mean_absolute_error: 4.7255
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 111.0656 - mean_absolute_error: 7.7652 - val_loss: 47.3292 - val_mean_absolute_error: 4.6619
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 116.2306 - mean_absolute_error: 8.1131 - val_loss: 46.6001 - val_mean_absolute_error: 4.6301
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 106.0482 - mean_absolute_error: 7.7600 - val_loss: 46.2203 - val_mean_absolute_error: 4.6054
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 147.7480 - mean_absolute_error: 8.8439 - val_loss: 46.4108 - val_mean_absolute_error: 4.6422
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 96.6787 - mean_absolute_error: 7.7682 - val_loss: 46.4280 - val_mean_absolute_error: 4.6345
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 94.9263 - mean_absolute_error: 7.4567 - val_loss: 48.0037 - val_mean_absolute_error: 4.7602
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 86.3023 - mean_absolute_error: 7.0303 - val_loss: 48.0034 - val_mean_absolute_error: 4.7767
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 97.8560 - mean_absolute_error: 7.4150 - val_loss: 46.6675 - val_mean_absolute_error: 4.7027
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.6133 - mean_absolute_error: 7.4187 - val_loss: 46.7618 - val_mean_absolute_error: 4.7514
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 90.5497 - mean_absolute_error: 7.4580 - val_loss: 48.8434 - val_mean_absolute_error: 4.8987
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 75.5376 - mean_absolute_error: 6.6413 - val_loss: 47.8606 - val_mean_absolute_error: 4.8211
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.5755 - mean_absolute_error: 7.5968 - val_loss: 46.8663 - val_mean_absolute_error: 4.7773
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 80.6072 - mean_absolute_error: 7.0665 - val_loss: 46.1858 - val_mean_absolute_error: 4.7717
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 85.4075 - mean_absolute_error: 7.1175 - val_loss: 44.7401 - val_mean_absolute_error: 4.7108
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 93.6288 - mean_absolute_error: 7.2540 - val_loss: 44.1215 - val_mean_absolute_error: 4.7001
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 88.1609 - mean_absolute_error: 6.9599 - val_loss: 44.6151 - val_mean_absolute_error: 4.7364
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 83.9713 - mean_absolute_error: 7.1351 - val_loss: 43.6442 - val_mean_absolute_error: 4.6573
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 107.8338 - mean_absolute_error: 7.9486 - val_loss: 43.7616 - val_mean_absolute_error: 4.6747
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.5394 - mean_absolute_error: 7.2064 - val_loss: 45.5020 - val_mean_absolute_error: 4.7960
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 92.6652 - mean_absolute_error: 7.3219 - val_loss: 44.8495 - val_mean_absolute_error: 4.7634
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 90.0515 - mean_absolute_error: 7.2980 - val_loss: 44.0493 - val_mean_absolute_error: 4.6830
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 105.0310 - mean_absolute_error: 7.9400 - val_loss: 40.7269 - val_mean_absolute_error: 4.4321
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 75.2133 - mean_absolute_error: 6.7938 - val_loss: 40.1265 - val_mean_absolute_error: 4.4191
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 89.5031 - mean_absolute_error: 7.1797 - val_loss: 40.2567 - val_mean_absolute_error: 4.4690
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 94.5397 - mean_absolute_error: 7.2647 - val_loss: 41.8249 - val_mean_absolute_error: 4.6296
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 116.4049 - mean_absolute_error: 8.0983 - val_loss: 41.4992 - val_mean_absolute_error: 4.6208
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 73.4133 - mean_absolute_error: 6.5799 - val_loss: 42.7553 - val_mean_absolute_error: 4.7551
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 110.3710 - mean_absolute_error: 8.1747 - val_loss: 41.8707 - val_mean_absolute_error: 4.6896
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 90.0003 - mean_absolute_error: 7.2258 - val_loss: 41.3206 - val_mean_absolute_error: 4.6873
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 82.6627 - mean_absolute_error: 6.8240 - val_loss: 40.7977 - val_mean_absolute_error: 4.6209

# %%
# Inspect the saved files (sorted by modification date, newest first)
# !ls -lt
# Out:
# total 3652
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch093_valloss40.13.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch092_valloss40.73.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch087_valloss43.64.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch085_valloss44.12.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch084_valloss44.74.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch083_valloss46.19.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch073_valloss46.22.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch072_valloss46.60.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch071_valloss47.33.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch070_valloss48.85.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch069_valloss50.37.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch067_valloss52.05.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch066_valloss52.14.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch065_valloss54.56.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch064_valloss55.89.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch063_valloss58.60.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch061_valloss59.84.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch060_valloss59.86.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch059_valloss60.98.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch058_valloss62.58.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch057_valloss63.53.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch056_valloss64.91.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch055_valloss67.50.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch053_valloss68.42.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch052_valloss69.57.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch051_valloss71.33.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch050_valloss73.79.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch049_valloss77.67.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch048_valloss81.18.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch047_valloss86.15.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch046_valloss90.33.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch045_valloss95.00.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch044_valloss100.82.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch043_valloss107.10.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch042_valloss114.91.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch041_valloss124.04.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch040_valloss133.36.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch039_valloss142.60.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch038_valloss150.49.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch037_valloss159.14.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch036_valloss167.77.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch035_valloss178.88.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch034_valloss189.53.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch033_valloss198.72.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch032_valloss206.10.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch031_valloss219.16.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch030_valloss233.41.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch029_valloss248.45.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch028_valloss264.52.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch027_valloss281.17.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch026_valloss298.90.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch025_valloss319.52.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch024_valloss336.03.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch023_valloss357.21.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch022_valloss373.76.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch021_valloss394.14.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch020_valloss413.74.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch019_valloss435.67.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch018_valloss454.66.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch017_valloss473.10.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch016_valloss491.18.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch015_valloss505.96.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch014_valloss521.64.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch013_valloss534.69.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch012_valloss547.97.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch011_valloss560.02.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch010_valloss571.56.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch009_valloss583.60.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch008_valloss593.30.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch007_valloss602.59.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch006_valloss611.13.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch005_valloss619.39.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch004_valloss627.29.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch003_valloss635.80.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch002_valloss643.93.keras
# -rw-r--r-- 1 root root 45450 Aug 27 20:07 bestmodel_epoch001_valloss652.98.keras
# drwxr-xr-x 1 root root  4096 Aug 26 13:24 sample_data

# %%
# Check the keys in 'history'
history.history.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
# Summarize history for MSE loss
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss (MSE)')
plt.ylabel('Mean Squared Error')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# Summarize history for MAE
plt.figure(figsize=(15,5))
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Metric (MAE)')
plt.ylabel('Mean Absolute Error')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# # 5. Evaluate the model on test set

# %% [markdown]
# Evaluate the model from the last epoch:

# %%
results = model.evaluate(x_test_norm, y_test, batch_size=50)
print( f"{model.metrics_names} = {results}" )
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 35.2659 - mean_absolute_error: 4.6560
# ['loss', 'compile_metrics'] = [36.844783782958984, 4.731746673583984]

# %% [markdown]
# Load the best model (which may not be the same as the model from the last epoch):

# %%
if save_weights_only:
  # Get the name of the newest .weights.h5 file
  files = [x for x in os.listdir('./') if x.endswith(".weights.h5")]
  newest = max(files , key=os.path.getctime)

  # Load weights of the best model
  best_model = create_model()     # Load the network architecture
  best_model.load_weights(newest) # Load weights
  print(f"Successfully loaded '{newest}' to 'best_model'")
else:
  # Get the name of the newest .keras file
  files = [x for x in os.listdir('./') if x.endswith(".keras")]
  newest = max(files , key=os.path.getctime)

  # Load the best model
  best_model = tf.keras.models.load_model(newest)
  print(f"Successfully loaded '{newest}' to 'best_model'")
# Out:
# Successfully loaded 'bestmodel_epoch093_valloss40.13.keras' to 'best_model'

# %% [markdown]
# Evaluate the model from the best epoch:

# %%
# If the model isn't compiled, there will be Error in .evaluate()
results = best_model.evaluate(x_test_norm, y_test, batch_size=50)
print( f"{best_model.metrics_names} = {results}" )
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 33.1273 - mean_absolute_error: 4.3787
# ['loss', 'compile_metrics'] = [34.702579498291016, 4.449447154998779]

# %% [markdown]
# # 6. Inference

# %%
# Predict one row of data
i = 0
y_pred0 = model.predict( x_test_norm[i].reshape(1,-1) )   # Reshape x_test[i] from (n_feature,) to (1, n_feature)
print(f'{y_pred0.shape=}')

# Inspect the result
print(f"x_test[{i}] = {x_test[i]}")
print(f"x_test_norm[{i}] = {x_test_norm[i]}")
print(f"y_test[{i}] = {y_test[i]}")
print(f"y_pred = {y_pred0}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# y_pred0.shape=(1, 1)
# x_test[0] = [ 18.0846   0.      18.1      0.       0.679    6.434  100.       1.8347
#   24.     666.      20.2     27.25    29.05  ]
# x_test_norm[0] = [ 1.55369355 -0.48361547  1.0283258  -0.25683275  1.03838067  0.23545815
#   1.11048828 -0.93976936  1.67588577  1.5652875   0.78447637 -3.48459553
#   2.25092074]
# y_test[0] = 7.2
# y_pred = [[8.732904]]

# %%
# Predict many rows of data at once
i,j = 2,21
y_preds = model.predict( x_test_norm[i:j] )
print(f'{y_preds.shape=}')

# Inspect the results
results = boston_dataframe(x_test[i:j], y_test)         # Create the test dataframe of 14 columns (13 features + 1 output)
results.rename(columns={'MEDV':'y_true'}, inplace=True) # Rename the last column from 'MEDV' to 'y_true'
results['y_pred'] = pd.Series(y_preds.squeeze())        # Append the prediction results as the rightmost column
results['Abs. Error'] = (results['y_true'] - results['y_pred']).abs()  # Compute Absolute Error betweeon 'y_true' and 'y_pred'
                                                                       # Append Absolute Error values as a new column

results.style.format(precision=2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# y_preds.shape=(19, 1)
# <style type="text/css">
# </style>
# <table id="T_3cb7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cb7d_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_3cb7d_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_3cb7d_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_3cb7d_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_3cb7d_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_3cb7d_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_3cb7d_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_3cb7d_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_3cb7d_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_3cb7d_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_3cb7d_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_3cb7d_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_3cb7d_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_3cb7d_level0_col13" class="col_heading level0 col13" >y_true</th>
#       <th id="T_3cb7d_level0_col14" class="col_heading level0 col14" >y_pred</th>
#       <th id="T_3cb7d_level0_col15" class="col_heading level0 col15" >Abs. Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cb7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3cb7d_row0_col0" class="data row0 col0" >0.05</td>
#       <td id="T_3cb7d_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_3cb7d_row0_col2" class="data row0 col2" >5.19</td>
#       <td id="T_3cb7d_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T